# %%
"""ans1)GET and POST are two commonly used methods in the HTTP protocol, which is the foundation of data communication on the World Wide Web. 
        These methods define how data is sent and received between a client (such as a web browser) and a server.

GET and POST are two commonly used methods in the HTTP protocol, which is the foundation of data communication on the World Wide Web.
These methods define how data is sent and received between a client (such as a web browser) and a server.

GET /api/users?id=123 HTTP/1.1
Host: example.com

POST method:
The POST method is used to submit or send data to be processed by the specified resource. 
When a client makes a POST request, it sends data as the payload of the HTTP request to the server.
The data is typically sent in the body of the request, and it can be in various formats such as JSON, XML, or form data.

POST /api/users HTTP/1.1
Host: example.com
Content-Type: application/json

{
  "name": "John",
  "email": "john@example.com"
}

# %%
"""ans2) In Flask, the request object is used to access and manipulate incoming HTTP requests made to the Flask application. 
It provides a way to extract information from the request made by a client, such as the data sent in the request, 
the HTTP method used, headers, query parameters, cookies, and more.

# %%
"""ans3) In Flask, the redirect() function is used to redirect the client's browser to a different URL.
It is a helpful feature that allows you to handle certain situations in your web application by redirecting the user to another page or route.

# %%
"""ans4) In Flask, templates are files that contain the structure and layout of web pages or email messages.
They are typically written in HTML and can include placeholders or dynamic content that gets filled in with data during runtime. 
Templates in Flask follow the Jinja template engine syntax, which provides additional features like conditionals, loops, and template inheritance.

The render_template() function is used to render and generate HTML pages by combining templates with dynamic data. 
It is a built-in function provided by Flask that takes a template file as input, along with any necessary data,
and produces the final HTML output that will be sent to the client's browser.

# %%
#ans5) 
from IPython.display import Image

Image(filename='output5.png')
